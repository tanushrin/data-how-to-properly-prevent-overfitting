# %% [markdown]
# ## Imports

# %%
# DATA MANIPULATION
import numpy as np

# DATA VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import StandardScaler

# BLOB DATASET
from sklearn.datasets import make_blobs

# KERAS
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
# Out:
# /Users/tanushrinayak/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-11-14 09:31:33.319872: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # How to Properly Prevent Overfitting

# %% [markdown]
# 🎯 **Goals of this challenge**
# - **`Cross Validate`** a Deep Learning Model
# - Give a **`Validation Set`** to the model
# - Apply two techniques to prevent overfitting:
#     - Use the **`Early Stopping`** criterion to prevent the Neural network from over-learning / over-fitting
#     - **`Regularize`** your network
# - Analyze the **`impact of the batch size and the number of epochs`** on the training of a Neural Network

# %% [markdown]
# ## Data - the `blobs` Dataset

# %% [markdown]
# ### Generating a Blobs Dataset
#
# First, let's generate some data using the [`make_blobs`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) function from Scikit-Learn
#
# Generate 2000 samples with 10 features each; there should be 8 classes of blobs (`centers` argument) with `cluster_std` equal to 7.

# %%
# YOUR CODE HERE
# Generate a blob dataset using
# make_blobs(n_samples=2000, centers=8, cluster_std=7, random_state=0) and
# 10 features. Store the data and targets in variables blobs_data and blobs_target.

blobs_data, blobs_target = make_blobs(n_samples=2000, centers=8, cluster_std=7, random_state=0, n_features=10)

print(blobs_data.shape)
print(blobs_target.shape)
# Out:
# (2000, 10)
# (2000,)

# %% [markdown]
# ### Visualizing the Dataset
#
# All your samples have 10 features. Plot one of the dimensions against another.

# %%
# YOUR CODE HERE
print(blobs_data[0])

# Plot the first feature vs. the second feature of the dataset using plt.scatter().
# Use the target variable to color the data points.

plt.scatter(blobs_data[:,0], blobs_data[:,1], c=blobs_target)
plt.show()
# Out:
# [-14.30676135  -4.00673556  10.51903968 -14.22412759  13.34968053
#   -0.76840797  -2.88471316 -10.89836562  -0.50526124   7.05283006]

# %% [markdown]
# ### Encoding your Categorical Target
#
# Use the 📚 [**to_categorical()**](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical) function to convert `y` to `y_cat`, which is the categorical representation of `y` with **One-Hot encoded** columns.

# %%
# YOUR CODE HERE
# Use to_categorical() to one-hot encode blobs_target. Store the result in variable y_cat.

y_cat = to_categorical(blobs_target)

print(y_cat.shape)
print(y_cat[0])
# Out:
# (2000, 8)
# [0. 0. 0. 0. 1. 0. 0. 0.]

# %% [markdown]
# ## (1) Cross-Validation in Deep Learning
#
# 👩🏻‍🏫 In a previous challenge, we split the dataset into a training set and a testing set at the beginning of the notebook. Then, we started to build different models which were trained on the training set and evaluated on the testing set.
#
# So, at the end of the day, we used the testing set every time we evaluated our models and different hyperparameters. This is normal: we always train on the training set and we evaluate on the testing set.
#
# However, we selected our "best model" based on the score of each model. In other words, we _used_ the test set to select our best model, which means there was ❗️ `data leakage` ❗️
#
# 🤔 **what should we do?**
#
# - A first good practice is to avoid using `random_state` or any deterministic separation between your training and testing sets. In that case, your testing set will change every time you re-run your notebook. This is far from being sufficient, though
# - To compare models properly, you have to run a cross-validation, a 10-fold split, for instance
#
# 🧐 If you look at [sklearn.model_selection.cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html), this Cross -Validation tool is designed for Machine Learning algorithms implemented in Scikit Learn, whereas we have been creating and using Neural Networks from Tensorflow/Keras.
#
# 🔥 Let's discover how to **Cross-validate a Neural Network**.

# %% [markdown]
# ### Designing a Neural Network
#
# First, write a function that generates a Neural Network with 3 layers:
#
# <u>Architecture</u>
# - an **input layer** with 25 neurons, the `relu` activation function and the appropriate `input_dim`
# - a **hidden layer** with 10 neurons and the `relu` activation function.
# - a **predictive layer** that is suited to the problem at hand (*multiclass classification*)
#
# <u>Compilation</u>
#
# The function should include a compilation method with:
# - the *categorical_crossentropy* loss
# - the *Adam* optimizer
# - the *accuracy* metric

# %%
def initialize_model():
    #  Generate a NN model with
    # an input layer with 25 neurons and ReLU activation,
    # a hidden layer with 10 neurons and ReLU activation,
    # output layer for multiclass classification.

    nn_model = models.Sequential([
        layers.Dense(25, activation='relu', input_shape=(10,)),
        layers.Dense(10, activation='relu'),
        layers.Dense(8, activation='softmax')
    ])

    return nn_model

# %% [markdown]
# ### Cross-Validating the Neural Net
#
# 🧑🏻‍💻 Write a _loop_ using the [K-Fold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) function from Scikit-Learn.
#
# * ✂️ Choose 10 splits to fit your model on the training data
# * 🧪 Evaluate your model on the testing data, and store the results of the evaluation into a `results` variable.
#
# _Hints_:
# * ⚖️ Do not forget to standardize your training data before fitting the NN
# * 👌 150 epochs should be sufficient for a first approximation
# * 🤝 As this is your first Deep Learning Cross-Validation, you are guided; just uncomment the following cell and follow the steps
# * ⏳ Notice that we added `%% time` at the beginning of this Jupyter Notebook cell to display its running time, and we encourage you to do so whenever you run expensive computations

# %%
# %%time
X = blobs_data
kf = KFold(n_splits=10)
kf.get_n_splits(X)

results = []

for train_index, test_index in kf.split(X):
    # Split the data into train and test sets
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y_cat[train_index], y_cat[test_index]


    # Scaling the data
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)


    # Initialize the model
    model = initialize_model()


    # Fit the model on the train set
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=100, verbose=0)


    # Evaluate the model on the test data
    results.append(model.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# CPU times: user 1min 34s, sys: 11 s, total: 1min 45s
# Wall time: 1min 3s

# %%
results
# Out:
# [0.7400000095367432,
#  0.75,
#  0.7649999856948853,
#  0.75,
#  0.7649999856948853,
#  0.7149999737739563,
#  0.7599999904632568,
#  0.7749999761581421,
#  0.7149999737739563,
#  0.7649999856948853]

# %% [markdown]
# ### Performance of the Cross-Validated Network
#
# Print the average accuracy of these 10 folds and the standard deviation of these 10 accuracy values.

# %%
#accuracy = [_[1] for _ in results]

# Store the average accuracy of the model in variable accuracy.
accuracy = np.array(results)

print(f'New mean accuracy: {np.mean(accuracy)*100:.2f}% (±{np.std(accuracy)*100:.2f})')
# Out:
# New mean accuracy: 75.00% (±1.99)

# %% [markdown]
# ### Remarks About the Computational Time
#
# - 🤯 You probably encountered one of the main drawbacks of using proper cross-validation for a Neural Network: **it takes a lot of time**! Therefore, for the rest of the Deep-Learning module, we will do **only one fold**
# - 👮🏻‍♀️ Remember that this is not entirely correct and, for real-life applications and problems, you are encouraged to use a proper cross-validation technique
# - 💼 In general, people split only once, as you did. Once they get to the end of their optimization, they launch a real cross-validation run at 6 PM, go home and get the final results on the next day

# %% [markdown]
# ### Holdout Method
#
# For the rest of the exercise (and of the Deep Learning module), split the dataset into a training set and a testing set with a 70/30% training-to-test data ratio.
#
# Make sure to also scale the data after splitting!

# %%
# YOUR CODE HERE
# Split the data into train and test sets using train_test_split() with test_size=0.3 and random_state=0.
# Store the results in X_train, X_test, y_train, y_test.

X_train, X_test, y_train, y_test = train_test_split(
    X, y_cat, test_size=0.3, random_state=0
)

# %%
# Scale the data
SScaler = StandardScaler()
SScaler.fit(X_train)

X_train_scaled = SScaler.transform(X_train)
X_test_scaled = SScaler.transform(X_test)

# %% [markdown]
# ## (2) How to Prevent a Neural Network from Overfitting?

# %% [markdown]
# ### (2.1) Early Stopping
#
# 🚦 **Stop the learning process before overfitting**

# %% [markdown]
# #### Illustrating How a Neural Network Easily Overfits
#
# First things first, let's show that if we train the model for too long (= for too many epochs) it will overfit the training data and will not be good at predicting the testing data.
#
# **How can we do it without using the testing data, which is strictly forbidden?**
#
# You can use a fraction of the <font color=blue>training set</font> as a <font color=green>validation set</font>.
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/lectures/deep-learning/02/validation_set.png" width=450>
#
# With Keras, you don't have to re-use the `train_test_split` method from Scikit-Learn. Instead, you have two options:
#
# - `validation_split = 0.2` (for example)
#     - The model will take the last 20% of the observations in the training set and use this group as the validation holdout set
#     - If you want a random `train_val_split` within the training set, you can also add the argument `shuffle = True` in `model.fit()`
# - `validation_data = (X_val, y_val)` if you have access to a dataset that you want to use as the validation holdout set.
#
# 👉 Let's go with the first option and set `epochs = 500`.
#
# 👉 Store the performances of the model in a `history` variable.

# %%
# %%time
# Cross validate using validation_split=0.3 and 500 epochs and
# use shuffle=True and early stopping with patience=5.

model = initialize_model()

early_stop = EarlyStopping(monitor='val_loss', patience=5)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(
    X_train_scaled, y_train, validation_split=0.3, epochs=500, verbose=0,
    #callbacks=[early_stop,],
    shuffle=True
)
# Out:
# CPU times: user 43.7 s, sys: 5.61 s, total: 49.3 s
# Wall time: 34 s

# %% [markdown]
# #### Your Neural Network's Performance
#
# Evaluate the model on the testing set and print the accuracy.

# %%
# YOUR CODE HERE
# Evaluate the model on the test data and store the results in variable test_loss, test_acc.

test_loss, test_acc = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f'Test loss: {test_loss:.2f}')
print(f'Test accuracy: {test_acc:.2f}')
# Out:
# Test loss: 1.24
# Test accuracy: 0.71

# %% [markdown]
# #### Learnings About Number of Epochs
#
# Plot the history of the model with the `plot_loss_accuracy()` function that we coded for you.
#
# What do you observe?

# %%
def plot_loss_accuracy(history, title=None):
    fig, ax = plt.subplots(1,2, figsize=(20,7))

    # --- LOSS ---

    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])

    ax[0].set_title('Model loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')

    ax[0].set_ylim((0,3))

    ax[0].legend(['Train', 'Test'], loc='best')

    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)

    # --- ACCURACY

    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])

    ax[1].set_title('Model Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epoch')

    ax[1].legend(['Train', 'Test'], loc='best')

    ax[1].set_ylim((0,1))

    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)

    if title:
        fig.suptitle(title)

# %%
# YOUR CODE HERE
# Plot the history of the model using plot_loss_accuracy().
# Set the title to 'Early Stopping'.

plot_loss_accuracy(history, title='Early Stopping')

# %% [markdown]
# 👩🏻‍🏫 We clearly see that **the number of epochs we choose has a strong influence on the final results**:
#
# **INSUFFICIENT NUMBER OF EPOCHS $\implies$ UNDERFITTING**:
# - The algorithm is not optimal as its Loss Function has **not converged yet**
# - It hasn't learned enough from the training data
#
# **TOO MANY EPOCHS** $\implies$ **OVERFITTING**:
# - Our Neural Network has **learned too much** from the training data, including its noisy information
# - the algorithm **does not generalize well** on test data
#
# 🚦 Basically, what we want to do is stop the algorithm **when the test loss is minimal** (or when the testing metrics are maximal)

# %% [markdown]
# #### Early Stopping
#
# 🧑🏻‍🏫 Let's introduce the **Early Stopping** criterion.
#
# The Early Stopping criterion is a way to **automatically stop the training of the algorithm** before reaching the number of epochs that was originally set.
#
# 🕵🏻‍♂️ **How does it work?**
#
# The model will pay attention to the **<font color=green>loss of the validation set</font>**. If <font color=green>it</font> starts increasing again 📈 while the <font color=blue>loss of the training set</font> keeps decreasing 📉, it is a good sign that the model is overfitting and the training should be stopped!
#
#
# <img src="validation_set.png" alt="Validation set" width=450/>

# %% [markdown]
# ##### Observing the Early Stopping Criterion
#
# Run the following code and plot the history.

# %%
# %%time

es = EarlyStopping()

model = initialize_model()

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 500,
    batch_size = 16,
    verbose = 1,
    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 4ms/step - loss: 1.9732 - accuracy: 0.2880 - val_loss: 1.8846 - val_accuracy: 0.3302
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.7335 - accuracy: 0.4219 - val_loss: 1.6623 - val_accuracy: 0.4751
# Epoch 3/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5045 - accuracy: 0.5781 - val_loss: 1.4389 - val_accuracy: 0.5677
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.2764 - accuracy: 0.6619 - val_loss: 1.2350 - val_accuracy: 0.6247
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.0906 - accuracy: 0.7038 - val_loss: 1.0780 - val_accuracy: 0.6698
# Epoch 6/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9541 - accuracy: 0.7242 - val_loss: 0.9645 - val_accuracy: 0.6817
# Epoch 7/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8604 - accuracy: 0.7375 - val_loss: 0.9033 - val_accuracy: 0.6817
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7972 - accuracy: 0.7436 - val_loss: 0.8550 - val_accuracy: 0.7031
# Epoch 9/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7540 - accuracy: 0.7477 - val_loss: 0.8307 - val_accuracy: 0.7078
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7203 - accuracy: 0.7528 - val_loss: 0.7997 - val_accuracy: 0.7078
# Epoch 11/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6961 - accuracy: 0.7559 - val_loss: 0.7900 - val_accuracy: 0.7173
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6762 - accuracy: 0.7559 - val_loss: 0.7870 - val_accuracy: 0.7055
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6599 - accuracy: 0.7620 - val_loss: 0.7704 - val_accuracy: 0.7268
# Epoch 14/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.7651 - val_loss: 0.7606 - val_accuracy: 0.7245
# Epoch 15/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6393 - accuracy: 0.7630 - val_loss: 0.7628 - val_accuracy: 0.7197
# CPU times: user 3.07 s, sys: 341 ms, total: 3.42 s
# Wall time: 2.51 s

# %% [markdown]
# ##### Evaluate the ES Model
#
# _(also look at the historical losses)_

# %%
# YOUR CODE HERE
test_loss, test_acc = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f'Test loss: {test_loss:.2f}')
print(f'Test accuracy: {test_acc:.2f}')

# Plot the history of the model using plot_loss_accuracy().
# Set the title to 'Early Stopping'.

plot_loss_accuracy(history, title='Early Stopping')
# Out:
# Test loss: 0.69
# Test accuracy: 0.76

# %% [markdown]
# ❗ **The problem with strict Early Stopping** ❗
#
# The problem with this type of approach is that as soon as the loss of the validation set increases, the model stops. However, as a Neural Network's convergence is stochastic, the loss may slightly increase before decreasing again.
#
# ✅ The `EarlyStopping` criterion has a `patience` keyword that defines how many **consecutive epochs without any loss decrease** are allowed in the validation set before we stop the training procedure.
#
# Use the `EarlyStopping` criterion with a patience term of 30 epochs, plot the results, and print the accuracy on the testing set

# %%
# %%time
# Early stopping with a patience term of 30 epochs.

es = EarlyStopping(patience=30)

model = initialize_model()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 500,
    batch_size = 16,
    verbose = 1,
    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 4ms/step - loss: 2.0618 - accuracy: 0.1818 - val_loss: 1.9730 - val_accuracy: 0.2755
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.9001 - accuracy: 0.3391 - val_loss: 1.8235 - val_accuracy: 0.3967
# Epoch 3/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.7030 - accuracy: 0.4443 - val_loss: 1.6207 - val_accuracy: 0.4608
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4658 - accuracy: 0.5077 - val_loss: 1.4060 - val_accuracy: 0.5059
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.2610 - accuracy: 0.5598 - val_loss: 1.2450 - val_accuracy: 0.5344
# Epoch 6/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.1138 - accuracy: 0.6108 - val_loss: 1.1284 - val_accuracy: 0.5677
# Epoch 7/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.0092 - accuracy: 0.6384 - val_loss: 1.0458 - val_accuracy: 0.6081
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9320 - accuracy: 0.6629 - val_loss: 0.9727 - val_accuracy: 0.6366
# Epoch 9/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8665 - accuracy: 0.6823 - val_loss: 0.9235 - val_accuracy: 0.6580
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8171 - accuracy: 0.6936 - val_loss: 0.8818 - val_accuracy: 0.6793
# Epoch 11/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7788 - accuracy: 0.7211 - val_loss: 0.8582 - val_accuracy: 0.6698
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7456 - accuracy: 0.7324 - val_loss: 0.8309 - val_accuracy: 0.6746
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7198 - accuracy: 0.7406 - val_loss: 0.8089 - val_accuracy: 0.6817
# Epoch 14/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6969 - accuracy: 0.7477 - val_loss: 0.8004 - val_accuracy: 0.6817
# Epoch 15/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6775 - accuracy: 0.7549 - val_loss: 0.7868 - val_accuracy: 0.7078
# Epoch 16/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6632 - accuracy: 0.7528 - val_loss: 0.7787 - val_accuracy: 0.7031
# Epoch 17/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6478 - accuracy: 0.7569 - val_loss: 0.7737 - val_accuracy: 0.6865
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6370 - accuracy: 0.7528 - val_loss: 0.7752 - val_accuracy: 0.7055
# Epoch 19/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6261 - accuracy: 0.7640 - val_loss: 0.7631 - val_accuracy: 0.7126
# Epoch 20/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6155 - accuracy: 0.7610 - val_loss: 0.7621 - val_accuracy: 0.7126
# Epoch 21/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6101 - accuracy: 0.7630 - val_loss: 0.7694 - val_accuracy: 0.7055
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6007 - accuracy: 0.7661 - val_loss: 0.7539 - val_accuracy: 0.7221
# Epoch 23/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5962 - accuracy: 0.7651 - val_loss: 0.7550 - val_accuracy: 0.7173
# Epoch 24/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5900 - accuracy: 0.7620 - val_loss: 0.7542 - val_accuracy: 0.7173
# Epoch 25/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5844 - accuracy: 0.7722 - val_loss: 0.7536 - val_accuracy: 0.7197
# Epoch 26/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5782 - accuracy: 0.7671 - val_loss: 0.7538 - val_accuracy: 0.7173
# Epoch 27/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5755 - accuracy: 0.7753 - val_loss: 0.7529 - val_accuracy: 0.7150
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5683 - accuracy: 0.7773 - val_loss: 0.7451 - val_accuracy: 0.7173
# Epoch 29/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5640 - accuracy: 0.7865 - val_loss: 0.7657 - val_accuracy: 0.7197
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5651 - accuracy: 0.7824 - val_loss: 0.7544 - val_accuracy: 0.7173
# Epoch 31/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5573 - accuracy: 0.7865 - val_loss: 0.7548 - val_accuracy: 0.7221
# Epoch 32/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5556 - accuracy: 0.7845 - val_loss: 0.7508 - val_accuracy: 0.7173
# Epoch 33/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5520 - accuracy: 0.7916 - val_loss: 0.7542 - val_accuracy: 0.7173
# Epoch 34/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5505 - accuracy: 0.7824 - val_loss: 0.7533 - val_accuracy: 0.7173
# Epoch 35/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5464 - accuracy: 0.7978 - val_loss: 0.7507 - val_accuracy: 0.7173
# Epoch 36/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5483 - accuracy: 0.7937 - val_loss: 0.7661 - val_accuracy: 0.7150
# Epoch 37/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.7957 - val_loss: 0.7632 - val_accuracy: 0.7245
# Epoch 38/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.7967 - val_loss: 0.7563 - val_accuracy: 0.7245
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5394 - accuracy: 0.7967 - val_loss: 0.7531 - val_accuracy: 0.7197
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.8018 - val_loss: 0.7500 - val_accuracy: 0.7245
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5367 - accuracy: 0.7967 - val_loss: 0.7547 - val_accuracy: 0.7245
# Epoch 42/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5345 - accuracy: 0.7957 - val_loss: 0.7481 - val_accuracy: 0.7221
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5337 - accuracy: 0.7967 - val_loss: 0.7531 - val_accuracy: 0.7221
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5289 - accuracy: 0.8029 - val_loss: 0.7596 - val_accuracy: 0.7197
# Epoch 45/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5288 - accuracy: 0.7957 - val_loss: 0.7531 - val_accuracy: 0.7197
# Epoch 46/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5258 - accuracy: 0.8059 - val_loss: 0.7589 - val_accuracy: 0.7197
# Epoch 47/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5274 - accuracy: 0.7998 - val_loss: 0.7545 - val_accuracy: 0.7221
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5230 - accuracy: 0.8029 - val_loss: 0.7594 - val_accuracy: 0.7197
# Epoch 49/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5196 - accuracy: 0.8059 - val_loss: 0.7604 - val_accuracy: 0.7173
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5198 - accuracy: 0.8008 - val_loss: 0.7610 - val_accuracy: 0.7245
# Epoch 51/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5181 - accuracy: 0.8008 - val_loss: 0.7568 - val_accuracy: 0.7197
# Epoch 52/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5150 - accuracy: 0.8049 - val_loss: 0.7607 - val_accuracy: 0.7173
# Epoch 53/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5159 - accuracy: 0.8039 - val_loss: 0.7559 - val_accuracy: 0.7197
# Epoch 54/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5159 - accuracy: 0.8069 - val_loss: 0.7598 - val_accuracy: 0.7173
# Epoch 55/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5109 - accuracy: 0.8121 - val_loss: 0.7628 - val_accuracy: 0.7173
# Epoch 56/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5100 - accuracy: 0.8121 - val_loss: 0.7655 - val_accuracy: 0.7221
# Epoch 57/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5108 - accuracy: 0.8121 - val_loss: 0.7640 - val_accuracy: 0.7197
# Epoch 58/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5057 - accuracy: 0.8100 - val_loss: 0.7604 - val_accuracy: 0.7173
# CPU times: user 9.65 s, sys: 1.05 s, total: 10.7 s
# Wall time: 7.88 s

# %%
# Print loss and accuracy on the test set
test_loss, test_acc = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f'Test loss: {test_loss:.2f}')
print(f'Test accuracy: {test_acc:.2f}')

# Plot the history of the model using plot_loss_accuracy().
# Set the title to 'Early Stopping'.

plot_loss_accuracy(history, title='Early Stopping')
# Out:
# Test loss: 0.68
# Test accuracy: 0.77

# %% [markdown]
# 🧑🏻‍🏫 **Remarks**
#
#
# - 📉 The model continues to converge even though its Loss Function had some consecutive loss increases/decreases w.r.t. to the number of epochs
# - 🤷🏻‍♂️ The `patience` number to select is highly related to the task at hand, and there is no general rule of thumb
# - 🧑🏻‍🏫 If you selected a high patience value for your Early Stopping:
#     - 🤞 your Neural Network should theoretically still stop training before the end (not always the case if your number of epochs is too low)
#     - ❗️ your validation loss will increase again after reaching a minimum value, but ideally, you want it to be as low as possible; the validation loss potentially reaches a minimum for certain weights at a certain epoch
#         - 🤔 How to find these weights?
#
# 📚 The `EarlyStopping` criterion enables you to:
# - stop the convergence
# - restore the best weights of the NN when it had the lowest error level (or the best score) on the validation set, thanks to `restore_best_weights = True` (set to `False` by default)

# %% [markdown]
# ##### Restoring the Best Weights of a Model
#
# - Run the model with an Early Stopping criterion that will restore the best weights of the Neural Net
# - Plot the loss and accuracy
# - Print the accuracy on the testing set

# %%
# %%time
# YOUR CODE HERE
# Run the model with an Early Stopping Criterion with patience=30 and
# with best weights restored.

es = EarlyStopping(patience=30, restore_best_weights=True)

model = initialize_model()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 500,
    batch_size = 16,
    verbose = 1,
    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 4ms/step - loss: 2.0968 - accuracy: 0.1593 - val_loss: 1.9706 - val_accuracy: 0.2233
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.8811 - accuracy: 0.3023 - val_loss: 1.8209 - val_accuracy: 0.3302
# Epoch 3/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.7085 - accuracy: 0.4106 - val_loss: 1.6514 - val_accuracy: 0.4133
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5126 - accuracy: 0.4934 - val_loss: 1.4496 - val_accuracy: 0.4917
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3032 - accuracy: 0.5679 - val_loss: 1.2605 - val_accuracy: 0.5629
# Epoch 6/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.1266 - accuracy: 0.6282 - val_loss: 1.1095 - val_accuracy: 0.6057
# Epoch 7/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9897 - accuracy: 0.6711 - val_loss: 0.9945 - val_accuracy: 0.6485
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8857 - accuracy: 0.7181 - val_loss: 0.9073 - val_accuracy: 0.6698
# Epoch 9/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8135 - accuracy: 0.7375 - val_loss: 0.8551 - val_accuracy: 0.6912
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7621 - accuracy: 0.7549 - val_loss: 0.8132 - val_accuracy: 0.6983
# Epoch 11/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7261 - accuracy: 0.7589 - val_loss: 0.7860 - val_accuracy: 0.7126
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7024 - accuracy: 0.7702 - val_loss: 0.7762 - val_accuracy: 0.7197
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.7671 - val_loss: 0.7605 - val_accuracy: 0.7173
# Epoch 14/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6636 - accuracy: 0.7753 - val_loss: 0.7523 - val_accuracy: 0.7150
# Epoch 15/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6522 - accuracy: 0.7681 - val_loss: 0.7398 - val_accuracy: 0.7150
# Epoch 16/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6381 - accuracy: 0.7794 - val_loss: 0.7338 - val_accuracy: 0.7221
# Epoch 17/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6285 - accuracy: 0.7794 - val_loss: 0.7336 - val_accuracy: 0.7173
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6226 - accuracy: 0.7804 - val_loss: 0.7293 - val_accuracy: 0.7268
# Epoch 19/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6159 - accuracy: 0.7814 - val_loss: 0.7362 - val_accuracy: 0.7245
# Epoch 20/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6078 - accuracy: 0.7886 - val_loss: 0.7301 - val_accuracy: 0.7173
# Epoch 21/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 0.7783 - val_loss: 0.7262 - val_accuracy: 0.7102
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5974 - accuracy: 0.7865 - val_loss: 0.7258 - val_accuracy: 0.7197
# Epoch 23/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5923 - accuracy: 0.7865 - val_loss: 0.7290 - val_accuracy: 0.7102
# Epoch 24/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5867 - accuracy: 0.7916 - val_loss: 0.7149 - val_accuracy: 0.7173
# Epoch 25/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5875 - accuracy: 0.7957 - val_loss: 0.7188 - val_accuracy: 0.7173
# Epoch 26/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5829 - accuracy: 0.7896 - val_loss: 0.7219 - val_accuracy: 0.7197
# Epoch 27/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5769 - accuracy: 0.7916 - val_loss: 0.7243 - val_accuracy: 0.7197
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5740 - accuracy: 0.7896 - val_loss: 0.7204 - val_accuracy: 0.7173
# Epoch 29/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5728 - accuracy: 0.7947 - val_loss: 0.7153 - val_accuracy: 0.7197
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.7967 - val_loss: 0.7216 - val_accuracy: 0.7126
# Epoch 31/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5676 - accuracy: 0.7916 - val_loss: 0.7239 - val_accuracy: 0.7126
# Epoch 32/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5654 - accuracy: 0.7916 - val_loss: 0.7259 - val_accuracy: 0.7173
# Epoch 33/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5600 - accuracy: 0.7957 - val_loss: 0.7226 - val_accuracy: 0.7221
# Epoch 34/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5603 - accuracy: 0.7947 - val_loss: 0.7249 - val_accuracy: 0.7197
# Epoch 35/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5578 - accuracy: 0.7988 - val_loss: 0.7290 - val_accuracy: 0.7150
# Epoch 36/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5548 - accuracy: 0.7947 - val_loss: 0.7260 - val_accuracy: 0.7245
# Epoch 37/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5568 - accuracy: 0.7967 - val_loss: 0.7323 - val_accuracy: 0.7197
# Epoch 38/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5471 - accuracy: 0.8018 - val_loss: 0.7250 - val_accuracy: 0.7173
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5478 - accuracy: 0.7978 - val_loss: 0.7395 - val_accuracy: 0.7150
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7988 - val_loss: 0.7302 - val_accuracy: 0.7268
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.7967 - val_loss: 0.7333 - val_accuracy: 0.7150
# Epoch 42/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5418 - accuracy: 0.8039 - val_loss: 0.7432 - val_accuracy: 0.7150
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.7947 - val_loss: 0.7472 - val_accuracy: 0.7150
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5399 - accuracy: 0.7988 - val_loss: 0.7360 - val_accuracy: 0.7150
# Epoch 45/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5371 - accuracy: 0.8018 - val_loss: 0.7378 - val_accuracy: 0.7173
# Epoch 46/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5357 - accuracy: 0.8039 - val_loss: 0.7374 - val_accuracy: 0.7078
# Epoch 47/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5332 - accuracy: 0.7998 - val_loss: 0.7351 - val_accuracy: 0.7102
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5345 - accuracy: 0.8029 - val_loss: 0.7465 - val_accuracy: 0.7031
# Epoch 49/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5326 - accuracy: 0.7988 - val_loss: 0.7383 - val_accuracy: 0.7102
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.8018 - val_loss: 0.7487 - val_accuracy: 0.7126
# Epoch 51/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.8059 - val_loss: 0.7459 - val_accuracy: 0.7102
# Epoch 52/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5241 - accuracy: 0.8090 - val_loss: 0.7439 - val_accuracy: 0.7197
# Epoch 53/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5243 - accuracy: 0.8059 - val_loss: 0.7463 - val_accuracy: 0.7150
# Epoch 54/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5217 - accuracy: 0.8090 - val_loss: 0.7438 - val_accuracy: 0.7102
# CPU times: user 9.03 s, sys: 1 s, total: 10 s
# Wall time: 7.32 s

# %%
#Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f'Test loss: {test_loss:.2f}')
print(f'Test accuracy: {test_acc:.2f}')

# Plot the history of the model using plot_loss_accuracy().
# Set the title to 'Early Stopping'.

plot_loss_accuracy(history, title='Early Stopping')
# Out:
# Test loss: 0.65
# Test accuracy: 0.76

# %% [markdown]
# 🥡 **Takeaways from the Early Stopping criterion:**
#
# - You can look at the 📚 [**Early Stopping documentation**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) to play with other parameters
# - You no longer need to have a look at the number of epochs as long as the model hits the stopping criterion. So, in the future, you should set a large number of epochs and the Early Stopping criterion will take care of stopping the training procedure before the model overfits!

# %% [markdown]
# ### (2.2) Batch Size & Epochs
#
# 🕵️‍♀️ Let's investigate the impact of the batch size on training a Neural Network and how we can use it to control how fast the parameters are updated.

# %% [markdown]
# #### Playing with the Batch Size
#
# Let's run the previous model with **different batch sizes** (with the Early Stopping criterion included) and plot the results.
#
# 👉 Run the following cell

# %%
# %%time
# RUN THIS CELL
es = EarlyStopping(patience=20, restore_best_weights=True)

for batch_size in [1, 4, 32]:

    model = initialize_model()

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(
        X_train_scaled,
        y_train,
        validation_split = 0.3,
        epochs = 500,
        batch_size = batch_size,
        verbose = 0,
        callbacks = [es]
    )

    results = model.evaluate(X_test_scaled, y_test, verbose=0)
    plot_loss_accuracy(history, title=f'------ BATCH SIZE {batch_size} ------\n The accuracy on the test set is of {results[1]:.2f}')
# Out:
# CPU times: user 1min 5s, sys: 6.59 s, total: 1min 12s
# Wall time: 50.4 s

# %% [markdown]
# #### ❓Question: Impact of the Batch Size on the Convergence of a Neural Network
#
# Look at the oscillations of the accuracy and the loss according to the batch size number.
#
# Is this coherent with what we saw when playing with the TensorFlow Playground?

# %% [markdown]
# > Your answer here

# %% [markdown]
# #### ❓Question: Number of Parameter Updates
#
# How many weight optimizations are done within one epoch (considering the number of observations and the batch size)? Does one epoch have more weight updates with a large or with a small batch size?

# %% [markdown]
# > Your answer here

# %% [markdown]
# #### Explanations
#
# Copy and paste this code into a new cell, run it, and observe.
#
# ```python
# print(f"There are {X_train.shape[0]} rows in the training set")
#
# batch_size = 16
# epochs = 2
#
# model = initialize_model()
#
# history = model.fit(
#     X_train_scaled,
#     y_train,
#     validation_split = 0.3,
#     epochs = epochs,
#     batch_size = batch_size,
#     verbose = 1
# )
# ```
#
#
# <u><b>Number of parameter updates:</b></u>
#
# - There are 1400 rows in the training set:
#     - $ 70 \% \times 1400 = 980 $ rows are used as the training set within the training set
#     - $ 30 \% \times 1400 = 420 $ rows are used as the validation set
# - For each epoch, we run a forward/backward propagation $ \large \lceil \frac{980}{batch size} \rceil = \lceil \frac{980}{16}\rceil = 62$ times
# - Without the Early Stopping Criterion, we will have _number of_ $ epochs \times 62 = 2 \times 62 = 124 $ iterations overall
#
# <u><b>Impact of the batch size:</b></u>
#
# The smaller the batch size
#
# $ \implies $ The more sub-iterations will be done
# $ \implies $ Parameters will be updated more frequently
# $ \implies $ We may need fewer epochs
#
# _(but we also don't care too much about the number of epochs if we use an Early Stopping Criterion with a patience term anyway)_

# %%
batch_size = 16
epochs = 2

model = initialize_model()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = epochs,
    batch_size = batch_size,
    verbose = 1
)
# Out:
# Epoch 1/2
# 62/62 [==============================] - 1s 4ms/step - loss: 2.0991 - accuracy: 0.1287 - val_loss: 2.0228 - val_accuracy: 0.1663
# Epoch 2/2
# 62/62 [==============================] - 0s 2ms/step - loss: 1.9196 - accuracy: 0.2268 - val_loss: 1.8679 - val_accuracy: 0.2114

# %% [markdown]
# ### (2.3) Regularization
#
# ❗️**Neural Networks with complex architectures can quickly lead to overfitting** (_too many layers and/or neurons_)❗️
#
# 🔥 But since Dense Neural Networks are just activated linear regressions, the weights can be constrained using L1, L2, or L1-L2 penalties!
#
# 🚓 So, let's apply some L2 or L1 penalties to these neurons; as in Machine Learning, these penalties are called **`Regularizers`**.
#
# 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/regularizers">See `tf.keras.regularizers`</a>

# %% [markdown]
# #### Observing Overfitting Before Regularizing
#
# First, let's initialize a model that has too many parameters for the task such that it overfits the training data quickly. To that purpose, let's not use any Early Stopping criterion.
#
# 🎁 Let's not waste time re-coding something that you are now used to, just run the following cell and observe what is happening 👇

# %%
# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 3. Training
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
    batch_size = 16,
    verbose=0
)

# 4. Evaluation
results_train = model.evaluate(X_train_scaled, y_train, verbose = 0)
results_test = model.evaluate(X_test_scaled, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the testing set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the testing set is 0.74...
# ...whereas the accuracy on the training set is 0.84!

# %% [markdown]
# ☝️ In our "over-parameterized network", some neurons became **too specific for the given training data**, preventing the network from generalizing to new data.
#
# 😕 This led to some overfitting!

# %% [markdown]
# #### Studying the Impact of Regularization on the Neural Network
#
# Change the previous code to integrate an L2 or L1 regularizer into your Dense Layers.

# %%
# YOUR CODE HERE
# Use L2 regularizer in the Dense layers

# 1. Model Architecture
model = models.Sequential()

model.add(layers.Dense(25, activation='relu', input_dim=10, kernel_regularizer=regularizers.l2(0.005)))
model.add(layers.Dense(10, activation='relu', kernel_regularizer=regularizers.l2(0.005)))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 3. Training
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
    batch_size = 16,
    verbose=0
)

# 4. Evaluation
results_train = model.evaluate(X_train_scaled, y_train, verbose = 0)
results_test = model.evaluate(X_test_scaled, y_test, verbose = 0)

# 5. Looking back at what happened during the training phase
print(f'The accuracy on the testing set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the testing set is 0.77...
# ...whereas the accuracy on the training set is 0.81!

# %% [markdown]
# ### (2.4) Dropout Layers

# %% [markdown]
# #### Introduction to Dropout Layers
#
# The role of a Dropout Layer is to randomly cancel the output of some neurons during the training phase, it prevents the network from getting too specific for the input data.
#
# Dropout Layers
# - ensure that no neuron can overspecialize in learning a pattern of the dataset because its output is sometimes canceled
# - force the information of an input to be spread across multiple neurons instead of only one specific neuron
# - are super straightforward to code 👌
#   - but what is going on _under the hood_? 👩🏻‍🏫

# %% [markdown]
# #### Optional Reading
#
# <details>
#     <summary>Click here for further explanations about Dropout Layers</summary>
#
# 🤔 Remember what we said about neurons becoming **too specific**?
#
# **`BEGIN_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
#
# ---
#
# ⚽️  **A Football Analogy:**
#
# Think about a football team. There are 11 players on the pitch, but there are also players on the bench. Why?
# - The coach may want to substitute injured or tired players during the game
# - The team may be
#     - losing the game and willing to substitute a midfielder with a more **versatile player** who can be more offensive (= **mix of** midfielder/attacker roles)
#     - winning the game and would like to secure the result by replacing a midfielder with a more **versatile player** who can be more defensive (= **mix of** midfielder/defense roles)
#
# 💡 Well, in a Neural Net, there is also a risk that a neuron over-specializes in detecting one pattern, where it would be advisable to keep it more versatile.
#
# ---
#
# 📚 **The goal of [Dropout Layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) is to prevent neurons from over-specializing.**
#
# 🧑🏻‍🏫 How do Dropout Layers work?
#
# 👉 When we apply a **Dropout rate** of 20% to a layer $k$, 20% of the **selected neurons** will have their weights **temporarily set to 0** , which has the following consequences:
# 1. A neuron computed at layer $k + 1$ considers all the weights as usual, but since some of them were temporarily set to 0, they were “ignored” while creating the neurons of this layer $k + 1$
# 2. Once a batch of data points has been seen by the Neural Network (**forward propagation**) and 80% of the weights in a layer have been optimized/updated (**backward propagation** with the **Adam** optimizer), the Neural Network moves on to the forward propagation of the next batch, where it will use:
#    - 80% of the weights; the ones that were updated
#    - 20% of the weights; the ones that were previously ignored and had their values **temporarily** set to 0
#
# Based on these weights, we will go through this Dropout Layer again, which is going to temporarily ignore another 20% of the weights of a given layer. Be careful, the selection of this 20% is random, so the weights that will be ignored this time won't necessarily be the same as before!
#
# 👉 Think about the **Dropout rate** as a **sampling with replacement**
#
# 👉 By **randomly shutting down** different neurons at different epochs, we force the data points to be **analyzed by different neurons**. At the end of the day, these neurons will become **more versatile** instead of over-specializing!
#
# ---
#
# **`END_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
# </details>

# %% [markdown]
# #### Studying the Impact of Dropout Layers on the Neural Network
#
# Include some Dropout layers in the architecture of your original model _(don't add regularizers here)_.
#
# What can you observe regarding the convergence of your model? What about its ability to generalize?

# %%
# YOUR CODE HERE
# Add dropout layers without regularization

# 1. Model Architecture
model = models.Sequential()

model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 3. Training
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
    batch_size = 16,
    verbose=0
)

# 4. Evaluation
results_train = model.evaluate(X_train_scaled, y_train, verbose = 0)
results_test = model.evaluate(X_test_scaled, y_test, verbose = 0)

# 5. Looking back at what happened during the training phase
print(f'The accuracy on the testing set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the testing set is 0.72...
# ...whereas the accuracy on the training set is 0.73!

# %% [markdown]
# ## (3) Conclusions
#
# - ❗️ If you train a Neural Network too much (too many layers, too many neurons, and/or too many epochs), it will overfit very quickly
# - 🥊 To prevent overfitting in Deep Learning, you can use Early Stopping, Regularization, and Dropout Layers
# - ❗️ Be careful, if you use these techniques, you might end up on the other spectrum of the performance where your model would underfit the dataset!
# - 🆗 You could potentially look at the batch size but we usually use 16 or 32; and as the French Computer Scientist [**Yann Lecun**](https://en.wikipedia.org/wiki/Yann_LeCun) said (Facebook x NYU):
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/deep_learning_yann_lecun_batch_size.png" alt="batch_size_yann_lecun" width="500">

# %% [markdown]
# ## 🏁 Congratulations!
#
# 💾 Do not forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move to the next challenge!
